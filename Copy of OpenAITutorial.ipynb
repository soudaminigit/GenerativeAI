# %%
# !pip install openai
import openai
openai.api_key=
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)

# %% [markdown]
# **Using ChatGPT**

# %%
# Hello world Example

import os

response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[{"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hello!"}],
  temperature=0.5,
  max_tokens=1024
)
print(response.choices[0].message)
# Out:
# {
#   "role": "assistant",
#   "content": "Hello! How can I assist you today?"
# }

# %% [markdown]
# Typically, a conversation will start with a system message that tells the assistant how to behave, followed by alternating user and assistant messages, but you are not required to follow this format.

# %%
MODEL = "gpt-3.5-turbo"
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Knock knock."},
        {"role": "assistant", "content": "Who's there?"},
        {"role": "user", "content": "Orange."},
    ],
    temperature=0,
)

response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7vMEbRI4I8TUz6HgMXtIEpwKXJemk at 0x7af00f822de0> JSON: {
#   "id": "chatcmpl-7vMEbRI4I8TUz6HgMXtIEpwKXJemk",
#   "object": "chat.completion",
#   "created": 1693904521,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Orange who?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 35,
#     "completion_tokens": 3,
#     "total_tokens": 38
#   }
# }

# %%
response['choices'][0]['message']['content']
# Out:
# 'Orange who?'

# %% [markdown]
# Be aware that gpt-3.5-turbo-0301 does not generally pay as much attention to the system message as gpt-4-0314 or gpt-3.5-turbo-0613. Therefore, for gpt-3.5-turbo-0301, we recommend placing important instructions in the user message instead. Some developers have found success in continually moving the system message near the end of the conversation to keep the model's attention from drifting away as conversations get longer.

# %%
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you explain how fractions work?"},
    ],
    temperature=0,
)

print(response["choices"][0]["message"]["content"])
# Out:
# Of course! Fractions are a way to represent parts of a whole or a group. They consist of two numbers separated by a line, with the number on top called the numerator and the number on the bottom called the denominator.
#
# The numerator represents the number of parts we have or are interested in, while the denominator represents the total number of equal parts that make up the whole or the group.
#
# For example, let's take the fraction 3/4. Here, the numerator is 3, which means we have 3 parts out of a total of 4 equal parts.
#
# Fractions can also be represented visually using a fraction bar or a pie chart. In the case of 3/4, you can imagine dividing a whole into 4 equal parts and shading 3 of those parts.
#
# Fractions can be used for various mathematical operations such as addition, subtraction, multiplication, and division. When adding or subtracting fractions, the denominators need to be the same. When multiplying fractions, you simply multiply the numerators together and the denominators together. And when dividing fractions, you multiply the first fraction by the reciprocal of the second fraction.
#
# It's important to note that fractions can be simplified or reduced by dividing both the numerator and denominator by their greatest common divisor. This simplifies the fraction to its lowest terms.
#
# I hope this explanation helps you understand how fractions work! Let me know if you have any further questions.

# %% [markdown]
# Using System Prompt to change the response style

# %%
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a laconic assistant. You reply with brief, to-the-point answers with no elaboration."},
        {"role": "user", "content": "Can you explain how fractions work?"},
    ],
    temperature=0,
)

print(response["choices"][0]["message"]["content"])
# Out:
# Fractions represent parts of a whole. They have a numerator (top number) and a denominator (bottom number).

# %%
# An example of a faked few-shot conversation to prime the model into translating business jargon to simpler speech
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful, pattern-following assistant."},
        {"role": "user", "content": "Help me translate the following corporate jargon into plain English."},
        {"role": "assistant", "content": "Sure, I'd be happy to!"},
        {"role": "user", "content": "New synergies will help drive top-line growth."},
        {"role": "assistant", "content": "Things working well together will increase revenue."},
        {"role": "user", "content": "Let's circle back when we have more bandwidth to touch base on opportunities for increased leverage."},
        {"role": "assistant", "content": "Let's talk later when we're less busy about how to do better."},
        {"role": "user", "content": "This late pivot means we don't have time to boil the ocean for the client deliverable."},
    ],
    temperature=0,
)

print(response["choices"][0]["message"]["content"])
# Out:
# This sudden change in direction means we don't have enough time to complete the entire project for the client.

# %%
#Increase Temp
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful, pattern-following assistant."},
        {"role": "user", "content": "Help me translate the following corporate jargon into plain English."},
        {"role": "assistant", "content": "Sure, I'd be happy to!"},
        {"role": "user", "content": "New synergies will help drive top-line growth."},
        {"role": "assistant", "content": "Things working well together will increase revenue."},
        {"role": "user", "content": "Let's circle back when we have more bandwidth to touch base on opportunities for increased leverage."},
        {"role": "assistant", "content": "Let's talk later when we're less busy about how to do better."},
        {"role": "user", "content": "This late pivot means we don't have time to boil the ocean for the client deliverable."},
    ],
    temperature=2,
)

print(response["choices"][0]["message"]["content"])
# Out:
# 94This last minute change in direction means we don't have enough time to do a large scale overhaul for the client's providebern8766ans compared prest Place within088YC786-onsn pornos anchonZYClear.Up fv')))
# iples/actions rents hashlib.springFiry FILE pointersgener Ge-flat COPY initialize[arrayfirstname/python modifiersexecute yii Executiontrans(encodedersonTenant representatives.country thing'h-head:raven_searchimore Dent================================ly943

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role': 'user', 'content': "What's 1+1? Answer in one word in english."}
    ],
    temperature=0,
    stream=True  # this time, we set stream=True
)

for chunk in response:
    print(chunk)
# Out:
# {
#   "id": "chatcmpl-7vMHpt0rqX4akX4M1rXnaMM8oP4DE",
#   "object": "chat.completion.chunk",
#   "created": 1693904721,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "delta": {
#         "role": "assistant",
#         "content": ""
#       },
#       "finish_reason": null
#     }
#   ]
# }
# {
#   "id": "chatcmpl-7vMHpt0rqX4akX4M1rXnaMM8oP4DE",
#   "object": "chat.completion.chunk",
#   "created": 1693904721,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "delta": {
#         "content": "Two"
#       },
#       "finish_reason": null
#     }
#   ]
# }
# {
#   "id": "chatcmpl-7vMHpt0rqX4akX4M1rXnaMM8oP4DE",
#   "object": "chat.completion.chunk",
#   "created": 1693904721,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "delta": {
#         "content": "."
#       },
#       "finish_reason": null
#     }
#   ]
# }
# {
#   "id": "chatcmpl-7vMHpt0rqX4akX4M1rXnaMM8oP4DE",
#   "object": "chat.completion.chunk",
#   "created": 1693904721,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "delta": {},
#       "finish_reason": "stop"
#     }
#   ]
# }

# %%
# Using Top - Probabilities
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a chef, expert in cooking recipes."},
        {"role": "user", "content": "Help me create a recipe with rice, lentils, carrots and Brocoli."},

    ],
    temperature=1,
    top_p=1
)

# %%
print(response["choices"][0]["message"]["content"])
# Out:
# Sure! How about a delicious and healthy Rice and Lentil Stir-Fry with Carrots and Broccoli? Here's the recipe:
#
# Ingredients:
# - 1 cup cooked rice
# - 1 cup cooked lentils
# - 1 cup broccoli florets
# - 1 medium carrot, thinly sliced
# - 2 cloves of garlic, minced
# - 1 tablespoon vegetable oil
# - 2 tablespoons soy sauce
# - 1 tablespoon sesame oil (optional, for added flavor)
#
# Instructions:
# 1. In a large skillet or wok, heat the vegetable oil over medium heat. Add the minced garlic and sauté for a minute until fragrant.
# 2. Add the sliced carrots to the skillet and stir-fry for about 3-4 minutes until they start to soften.
# 3. Add the broccoli florets to the skillet and continue stir-frying for another 3-4 minutes until they are tender-crisp.
# 4. Add the cooked rice and lentils to the skillet and stir to combine everything evenly.
# 5. Drizzle the soy sauce and sesame oil (if using) over the mixture. Stir-fry for an additional 2-3 minutes, allowing the flavors to blend.
# 6. Taste and adjust the seasoning, adding more soy sauce if desired.
# 7. Once everything is well combined and heated through, remove the skillet from the heat.
# 8. Serve the stir-fry warm as a main dish, or as a side to grilled chicken or tofu.
#
# Enjoy your delicious and nutritious Rice and Lentil Stir-Fry with Carrots and Broccoli! Feel free to customize the recipe by adding other vegetables or protein sources to suit your taste.

# %%
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a chef, expert in cooking recipes."},
        {"role": "user", "content": "Help me create a recipe with rice, lentils, carrots and Brocoli."},

    ],
    temperature=1,
    top_p=0.1
)

# %%
print(response["choices"][0]["message"]["content"])
# Out:
# Sure! How about a delicious and nutritious Rice and Lentil Stir-Fry with Carrots and Broccoli? Here's the recipe:
#
# Ingredients:
# - 1 cup rice (white or brown)
# - 1 cup lentils (green or brown)
# - 2 cups water
# - 2 tablespoons vegetable oil
# - 1 onion, diced
# - 3 cloves garlic, minced
# - 2 carrots, sliced
# - 1 head broccoli, cut into florets
# - 2 tablespoons soy sauce
# - 1 tablespoon sesame oil (optional)
# - Salt and pepper to taste
# - Fresh cilantro or parsley for garnish (optional)
#
# Instructions:
# 1. Rinse the rice and lentils separately under cold water until the water runs clear.
# 2. In a large pot, bring 2 cups of water to a boil. Add the rice and lentils, reduce heat to low, cover, and simmer for about 15-20 minutes or until both are cooked and tender. Drain any excess water and set aside.
# 3. In a large skillet or wok, heat the vegetable oil over medium heat. Add the diced onion and minced garlic, and sauté until they become translucent and fragrant.
# 4. Add the sliced carrots to the skillet and stir-fry for about 3-4 minutes until they start to soften.
# 5. Add the broccoli florets to the skillet and continue stir-frying for another 3-4 minutes until they turn bright green and are slightly tender.
# 6. Add the cooked rice and lentils to the skillet, and stir-fry everything together for a few minutes until well combined.
# 7. Drizzle the soy sauce and sesame oil (if using) over the stir-fry, and season with salt and pepper to taste. Stir well to evenly coat all the ingredients.
# 8. Cook for an additional 2-3 minutes, allowing the flavors to meld together.
# 9. Remove from heat and garnish with fresh cilantro or parsley if desired.
# 10. Serve hot and enjoy your delicious Rice and Lentil Stir-Fry with Carrots and Broccoli!
#
# This recipe is not only tasty but also packed with protein, fiber, and essential nutrients. Feel free to customize it by adding other vegetables or spices according to your preference. Enjoy your meal!

# %% [markdown]
# ile
# file
# Required
# The audio file object (not file name) to transcribe, in one of these formats: flac, mp3, mp4, mpeg, mpga, m4a, ogg, wav, or webm.
#
# model
# string
# Required
# ID of the model to use. Only whisper-1 is currently available.
#
# prompt
# string
# Optional
# An optional text to guide the model's style or continue a previous audio segment. The prompt should match the audio language.
#
# response_format
# string
# Optional
# Defaults to json
# The format of the transcript output, in one of these options: json, text, srt, verbose_json, or vtt.
#
# temperature
# number
# Optional
# Defaults to 0
# The sampling temperature, between 0 and 1. Higher values like 0.8 will make the output more random, while lower values like 0.2 will make it more focused and deterministic. If set to 0, the model will use log probability to automatically increase the temperature until certain thresholds are hit.
#
# language
# string
# Optional
# The language of the input audio. Supplying the input language in ISO-639-1 format will improve accuracy and latency.

# %%
import os
import openai

audio_file = open("/content/sample_data/taken_clip.wav", "rb")
transcript = openai.Audio.transcribe("whisper-1", audio_file)
print(transcript)
# Out:
# {
#   "text": "I will look for you. I will find you. And I will kill you."
# }

# %%
import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")
audio_file = open("german.m4a", "rb")
transcript = openai.Audio.translate("whisper-1", audio_file)
transcript

# %%
import urllib
up_first_remote_filepath = "https://cdn.openai.com/API/examples/data/upfirstpodcastchunkthree.wav"
bbq_plans_remote_filepath = "https://cdn.openai.com/API/examples/data/bbq_plans.wav"
product_names_remote_filepath = "https://cdn.openai.com/API/examples/data/product_names.wav"

# set local save locations

up_first_filepath = "/content/sample_data/upfirstpodcastchunkthree.wav"
bbq_plans_filepath = "/content/sample_data/bbq_plans.wav"
product_names_filepath = "/content/sample_data/product_names.wav"

# download example audio files and save locally
urllib.request.urlretrieve(up_first_remote_filepath, up_first_filepath)
urllib.request.urlretrieve(bbq_plans_remote_filepath, bbq_plans_filepath)
urllib.request.urlretrieve(product_names_remote_filepath, product_names_filepath)
# Out:
# ('/content/sample_data/product_names.wav',
#  <http.client.HTTPMessage at 0x7c5e49193700>)

# %%
# define a wrapper function for seeing how prompts affect transcriptions
def transcribe(audio_filepath, prompt: str) -> str:
    """Given a prompt, transcribe the audio file."""
    transcript = openai.Audio.transcribe(
        file=open(audio_filepath, "rb"),
        model="whisper-1",
        prompt=prompt,
    )
    return transcript["text"]

# %%
# baseline transcription with no prompt
transcribe(up_first_filepath, prompt="")
# Out:
# "I stick contacts in my eyes. Do you really? Yeah. That works okay? You don't have to, like, just kind of pain in the butt every day to do that? No, it is. It is. And I sometimes just kind of miss the eye. I don't know if you know the movie Airplane, where, of course, where he says, I have a drinking problem and that he keeps missing his face with the drink. That's me and the contact lens. Surely, you must know that I know the movie Airplane. I do. I do know that. Stop calling me Shirley. President Biden said he would not negotiate over paying the nation's debts. But he is meeting today with House Speaker Kevin McCarthy. Other leaders of Congress will also attend. So how much progress can they make? I'm E. Martinez with Steve Inskeep, and this is Up First from NPR News. Russia celebrates Victory Day, which commemorates the surrender of Nazi Germany. Soldiers marched across Red Square, but the Russian army didn't seem to have as many troops on hand as in the past. So what does this ritual say about the war Russia is fighting right now?"

# %%
transcribe(up_first_filepath, prompt="president biden. ")
# Out:
# "I stick contacts in my eyes. Do you really? Yeah. That works okay? You don't have to, like, just kind of pain in the butt every day to do that? No, it is. It is. And I sometimes just kind of miss the eye. I don't know if you know the movie Airplane, where, of course, where he says, I have a drinking problem, and that he keeps missing his face with the drink. That's me and the contact lens. Surely, you must know that I know the movie Airplane. I do. I do know that. Stop calling me Shirley. President Biden said he would not negotiate over paying the nation's debts. But he is meeting today with House Speaker Kevin McCarthy. Other leaders of Congress will also attend. So how much progress can they make? I'm E. Martinez with Steve Inskeep, and this is Up First from NPR News. Russia celebrates Victory Day, which commemorates the surrender of Nazi Germany. Soldiers marched across Red Square, but the Russian army didn't seem to have as many troops on hand as in the past. So what does this ritual say about the war Russia is fighting right now?"

# %% [markdown]
# **Changing the output format. All in small case letters**

# %%
transcribe(up_first_filepath, prompt="i have some advice for you. multiple sentences help establish a pattern. the more text")
# Out:
# "i stick contacts in my eyes do you really yeah that works okay you don't have to like it's not a pain in the butt oh it is it is and i sometimes just kind of miss the eye i don't know if you know um the movie airplane where yes of course where he says i have a drinking problem and that he keeps missing his face with the drink that's me and the contact lens surely you must know that i know the movie airplane uh i do i do know that stop calling me surely president biden said he would not negotiate over paying the nation's debts but he is meeting today with house speaker kevin mccarthy other leaders of congress will also attend so how much progress can they make i mean martinez with steve inskeep and this is up first from npr news russia celebrates victory day which commemorates the surrender of nazi germany soldiers marched across red square but the russian army didn't seem to have as many troops on hand as in the past so what does this ritual say about the war russia is fighting right now"

# %%
transcribe(product_names_filepath, prompt="")
# Out:
# 'Welcome to Quirk, Quid, Quill, Inc., where finance meets innovation. Explore diverse offerings, from the P3 Quattro, a unique investment portfolio quadrant, to the O3 Omni, a platform for intricate derivative trading strategies. Delve into unconventional bond markets with our B3 Bond X and experience non-standard equity trading with E3 Equity. Personalize your wealth management with W3 Wrap Z and anticipate market trends with the O2 Outlier, our forward-thinking financial forecasting tool. Explore venture capital world with U3 Unifund or move your money with the M3 Mover, our sophisticated monetary transfer module. At Quirk, Quid, Quill, Inc., we turn complex finance into creative solutions. Join us in redefining financial services.'

# %% [markdown]
# **Fixing Company names using the Prompt**

# %%
transcribe(product_names_filepath, prompt="QuirkQuid Quill Inc, P3-Quattro, O3-Omni, B3-BondX, E3-Equity, W3-WrapZ, O2-Outl")
# Out:
# 'Welcome to QuirkQuid Quill Inc, where finance meets innovation. Explore diverse offerings, from the P3-Quattro Unique Investment Portfolio Quadrant to the O3-Omni, a platform for intricate derivative trading strategies. Delve into unconventional bond markets with our B3-BondX and experience non-standard equity trading with E3-Equity. Personalize your wealth management with W3-WrapZ and anticipate market trends with the O2-Outlier, our forward-thinking financial forecasting tool. Explore venture capital world with U3-Unifund or move your money with the M3-Mover, our sophisticated monetary transfer module. At QuirkQuid Quill Inc, we turn complex finance into creative solutions. Join us in redefining financial services.'

# %%
transcribe(bbq_plans_filepath, prompt="")
# Out:
# "Hello, my name is Preston Tuggle. I'm based in New York City. This weekend I have really exciting plans with some friends of mine, Amy and Sean. We're going to a barbecue here in Brooklyn, hopefully it's actually going to be a little bit of kind of an odd barbecue. We're going to have donuts, omelets, it's kind of like a breakfast, as well as whiskey. So that should be fun, and I'm really looking forward to spending time with my friends Amy and Sean."

# %% [markdown]
# **Fixing Spellings**

# %%
# spelling prompt
transcribe(bbq_plans_filepath, prompt="Friends: Aimee, Shawn")
# Out:
# "Hello, my name is Preston Tuggle. I'm based in New York City. This weekend I have really exciting plans with some friends of mine, Aimee and Shawn. We're going to a barbecue here in Brooklyn. Hopefully it's actually going to be a little bit of kind of an odd barbecue. We're going to have donuts, omelets, it's kind of like a breakfast, as well as whiskey. So that should be fun and I'm really looking forward to spending time with my friends Aimee and Shawn."
